# %%
import matplotlib.pyplot as plt

# %%
## Bar plot

data= {
    'Graphene': 1.22,
    'SW': 1.38,
    'N-graphene': 1.38,
    'N-SW': 0.36,
    'Zig-edge': 1.36,
    'Zig-SW': 1.36,
    'Zig-N': 1.78,
    'Zig-Carboxyl': 0.15,
    'Arm-edge': 1.61,
    'Arm-SW': 1.53,
    'Arm-N': 1.33,
    'Arm-carboxyl': 1.23
}

# %%
Structure = list(data.keys())
G = list(data.values())

# %%
fig= plt.figure (figsize=(6,4),dpi=1080)
ax = fig.add_subplot(111)
plt.rcParams.update({'font.size': 10})



for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2.5)  # change width
    ax.spines[axis].set_color('black')




plt.bar('Graphene', 1.22, color ='#32CD32',edgecolor ='grey')
plt.bar('SW', 1.38, color ='#3CB371',edgecolor ='grey')
plt.bar('N-graphene', 1.38, color ='#2E8B57',edgecolor ='grey')
plt.bar('N-SW', 0.36, color ='#228B22',edgecolor ='grey')
plt.bar('Zig-edge', 1.36, color ='#0000FF',edgecolor ='grey')
plt.bar('Zig-SW', 1.36, color ='#4169E1',edgecolor ='grey')
plt.bar('Zig-N', 1.78, color ='#40E0D0',edgecolor ='grey')
plt.bar('Zig-Carboxyl', 0.15, color ='#00FFFF',edgecolor ='grey')
plt.bar('Arm-edge', 1.61, color ='#FF0000',edgecolor ='grey')
plt.bar('Arm-SW', 1.53, color ='#DC143C',edgecolor ='grey')
plt.bar('Arm-N', 1.33, color ='#CD5C5C',edgecolor ='grey')
plt.bar('Arm-carboxyl', 1.23, color ='#B22222',edgecolor ='grey')

fig.autofmt_xdate()


plt.plot([-1, 12], [0.73, 0.73],  '--',color='black', lw=2)
plt.xlim([-1, 12])

plt.tick_params(bottom=False)

plt.show()
